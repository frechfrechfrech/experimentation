# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/alex/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Data from https://bchi.bigcitieshealth.org/indicators/1827/searches/23468

# %%
data = pd.read_csv('Current BCHI Platform Dataset (8-01) - Updated BCHI Platform Dataset - BCHI, Phase I & II.csv')
# Out:
# /home/alex/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.tail()
# Out:
#                 Indicator Category           Indicator  \
# 35795  Social and Economic Factors  Percent Unemployed
# 35796  Social and Economic Factors  Percent Unemployed
# 35797  Social and Economic Factors  Percent Unemployed
# 35798  Social and Economic Factors  Percent Unemployed
# 35799  Social and Economic Factors  Percent Unemployed
#
#       Shortened Indicator Name Shortened Indicator Name (Graph)  Year     Sex  \
# 35795             Unemployment                              NaN  2014    Both
# 35796             Unemployment                              NaN  2014    Both
# 35797             Unemployment                              NaN  2014    Both
# 35798             Unemployment                              NaN  2014  Female
# 35799             Unemployment                              NaN  2014    Male
#
#       Race/Ethnicity Value           Place  \
# 35795          Black  17.0  Washington, DC
# 35796       Hispanic   5.8  Washington, DC
# ...

# %%
data['Shortened Indicator Name'].unique()
# Out:
# array(['Opioid-Related Overdose Mortality Rate', 'Adult Binge Drinking',
#        'Teen Binge Drinking', 'All Types of Cancer Mortality Rate',
#        'Female Breast Cancer Mortality Rate',
#        'Lung Cancer Mortality Rate',
#        'Asthma Emergency Department Visit Rate',
#        'Diabetes Mortality Rate', 'Heart Disease Mortality Rate',
#        'Adult Obesity', 'Adult Smoking', 'Adult Physical Activity Levels',
#        'Teen Obesity', 'Teen Smoking', 'Teen Physical Activity Levels',
#        'Foreign Born Population', 'Aging Population', 'Youth Population',
#        'Disability', 'English Speaking Population',
#        'Spanish Speaking Population', 'Race/Ethnicity', 'Sex',
#        'Total Population', 'Bike Score', 'Transit Score', 'Walkability',
#        "Children's Blood Lead Levels", 'Salmonella Infections',
#        'E.coli Infections', 'AIDS Diagnoses Rate', 'HIV Diagnoses Rate',
#        'HIV-Related Mortality Rate', 'Persons Living with HIV/AIDS Rate',
# ...

# %%
op = data[data['Shortened Indicator Name'] == 'Opioid-Related Overdose Mortality Rate']
op.head()
# Out:
#                   Indicator Category  \
# 0  Behavioral Health/Substance Abuse
# 1  Behavioral Health/Substance Abuse
# 2  Behavioral Health/Substance Abuse
# 3  Behavioral Health/Substance Abuse
# 4  Behavioral Health/Substance Abuse
#
#                                            Indicator  \
# 0  Opioid-Related Unintentional Drug Overdose Mor...
# 1  Opioid-Related Unintentional Drug Overdose Mor...
# 2  Opioid-Related Unintentional Drug Overdose Mor...
# 3  Opioid-Related Unintentional Drug Overdose Mor...
# 4  Opioid-Related Unintentional Drug Overdose Mor...
#
#                  Shortened Indicator Name Shortened Indicator Name (Graph)  \
# 0  Opioid-Related Overdose Mortality Rate                              NaN
# 1  Opioid-Related Overdose Mortality Rate                              NaN
# 2  Opioid-Related Overdose Mortality Rate                              NaN
# 3  Opioid-Related Overdose Mortality Rate                              NaN
# ...

# %%
op.groupby(['Year','Place'])['Indicator'].count()
# Out:
# Year  Place
# 2010  Columbus, OH                        8
#       Denver, CO                          8
#       Fort Worth (Tarrant County), TX    16
#       Kansas City, MO                     5
#       Las Vegas (Clark County), NV        8
#       Oakland (Alameda County), CA        2
#       San Antonio, TX                     8
#       San Diego County, CA                8
#       U.S. Total                          8
#       Washington, DC                      1
# 2011  Boston, MA                          4
#       Columbus, OH                        8
#       Denver, CO                          8
#       Fort Worth (Tarrant County), TX    16
#       Houston, TX                         5
#       Kansas City, MO                     5
#       Las Vegas (Clark County), NV        8
#       Minneapolis, MN                     9
#       Oakland (Alameda County), CA        2
#       Phoenix, AZ                         9
#       San Antonio, TX                     6
# ...
